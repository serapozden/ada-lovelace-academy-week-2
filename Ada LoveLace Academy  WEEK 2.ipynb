# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.DataFrame({
    "Name":["Hope Carpenter","Hill Cox", "Beck Foreman","Glory Richardson"],
    "Age":[44,15,68,25],
    "sex":["male","female","female","female"]
})
df
# Out:
#                Name  Age     sex
# 0    Hope Carpenter   44    male
# 1          Hill Cox   15  female
# 2      Beck Foreman   68  female
# 3  Glory Richardson   25  female

# %%
df["Age"]
# Out:
# 0    44
# 1    15
# 2    68
# 3    25
# Name: Age, dtype: int64

# %%
ages=pd.Series([44,15,68,25])
ages
# Out:
# 0    44
# 1    15
# 2    68
# 3    25
# dtype: int64

# %%
df["Age"].max()
# Out:
# 68

# %%
ages.max()
# Out:
# 68

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   38.000000
# std    23.338095
# min    15.000000
# 25%    22.500000
# 50%    34.500000
# 75%    50.000000
# max    68.000000

# %%
titanic=pd.read_csv("tested.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.to_excel("titanic.xlsx",sheet_name="passengers",index=False)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
ages=titanic["Age"]
ages.head()
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %%
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %%
titanic["Age"].shape
# Out:
# (418,)

# %%
big_35=titanic[titanic["Age"]>35]
big_35.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 11          903         0       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
#
#     Parch       Ticket     Fare Cabin Embarked
# 1       0       363272   7.0000   NaN        S
# 2       0       240276   9.6875   NaN        Q
# 11      0          694  26.0000   NaN        S
# 13      0        24065  26.0000   NaN        S
# 14      0  W.E.P. 5734  61.1750   E31        S

# %%
class_=titanic[titanic["Pclass"].isin([1,3])]
class_.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# 5     7538   9.2250   NaN        S

# %%
class_=titanic[(titanic["Pclass"]==1) | (titanic["Pclass"]==3)]
class_.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# 5     7538   9.2250   NaN        S

# %%
age_no=titanic[titanic["Age"].notna()]
age_no.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
adult_names=titanic.loc[titanic["Age"]>40]
adult_names.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 11          903         0       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
#
#     Parch       Ticket     Fare Cabin Embarked
# 1       0       363272   7.0000   NaN        S
# 2       0       240276   9.6875   NaN        Q
# 11      0          694  26.0000   NaN        S
# 13      0        24065  26.0000   NaN        S
# 14      0  W.E.P. 5734  61.1750   E31        S

# %%
adult_names=titanic.loc[titanic["Age"]>40,"Name"]
adult_names.head()
# Out:
# 1                      Wilkes, Mrs. James (Ellen Needs)
# 2                             Myles, Mr. Thomas Francis
# 11                           Jones, Mr. Charles Cresson
# 13                                 Howard, Mr. Benjamin
# 14    Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# Name: Name, dtype: object

# %%
titanic.iloc[8:20,0:6]
# Out:
#     PassengerId  Survived  Pclass  \
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 9                             Davies, Mr. John Samuel    male  21.0
# 10                                   Ilieff, Mr. Ylio    male   NaN
# 11                         Jones, Mr. Charles Cresson    male  46.0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 13                               Howard, Mr. Benjamin    male  63.0
# ...

# %%
null=titanic.iloc[0:4,4]="null"
null
# Out:
# 'null'

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    null  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    null  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    null  62.0      0      0
# 3                              Wirz, Mr. Albert    null  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic["Age"].mean()
# Out:
# 30.272590361445783

# %%
titanic[["Age","Fare"]].median()
# Out:
# Age     27.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Age","Fare"]].describe()
# Out:
#               Age        Fare
# count  332.000000  417.000000
# mean    30.272590   35.627188
# std     14.181209   55.907576
# min      0.170000    0.000000
# 25%     21.000000    7.895800
# 50%     27.000000   14.454200
# 75%     39.000000   31.500000
# max     76.000000  512.329200

# %%
titanic.agg({
    "Age":["min","max","median"],
    "Fare":["min","max","median"]
})
# Out:
#           Age      Fare
# min      0.17    0.0000
# max     76.00  512.3292
# median  27.00   14.4542

# %%
titanic[["Sex","Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  30.139603
# male    30.110941
# null    42.625000

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    30.139603
# male      30.110941
# null      42.625000
# Name: Age, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
titanic.sort_values(by="Age",ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 236         1128         0       1
# 305         1197         1       1
# 179         1071         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 96       0     19877   78.8500      C46        S
# 81       0  PC 17483  221.7792  C55 C57        S
# 236      0    110813   75.2500      D37        C
# 305      1    112901   26.5500      B26        S
# ...

# %%
titanic.sort_values(by=["Pclass","Age"],ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass  \
# 152         1044         0       3
# 25           917         0       3
# 1            893         1       3
# 19           911         1       3
# 309         1201         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 152                          Storey, Mr. Thomas    male  60.5      0      0
# 25                      Robins, Mr. Alexander A    male  50.0      1      0
# 1              Wilkes, Mrs. James (Ellen Needs)    null  47.0      1      0
# 19        Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0      0
# 309  Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1      0
#
#         Ticket     Fare Cabin Embarked
# 152       3701      NaN   NaN        S
# 25   A/5. 3337  14.5000   NaN        S
# 1       363272   7.0000   NaN        S
# 19        2696   7.2250   NaN        C
# 309     350026  14.1083   NaN        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic["Name"].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
titanic["Name"].str.split(",")
# Out:
# 0                                  [Kelly,  Mr. James]
# 1                  [Wilkes,  Mrs. James (Ellen Needs)]
# 2                         [Myles,  Mr. Thomas Francis]
# 3                                  [Wirz,  Mr. Albert]
# 4      [Hirvonen,  Mrs. Alexander (Helga E Lindqvist)]
#                             ...
# 413                              [Spector,  Mr. Woolf]
# 414                    [Oliva y Ocana,  Dona. Fermina]
# 415                    [Saether,  Mr. Simon Sivertsen]
# 416                             [Ware,  Mr. Frederick]
# 417                        [Peter,  Master. Michael J]
# Name: Name, Length: 418, dtype: object

# %%
titanic['Real_Name']=titanic["Name"].str.split(",").str.get(0)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    null  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    null  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    null  62.0      0      0
# 3                              Wirz, Mr. Albert    null  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked Real_Name
# 0   330911   7.8292   NaN        Q     Kelly
# 1   363272   7.0000   NaN        S    Wilkes
# 2   240276   9.6875   NaN        Q     Myles
# 3   315154   8.6625   NaN        S      Wirz
# 4  3101298  12.2875   NaN        S  Hirvonen

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C
#
#          Real_Name
# 413        Spector
# 414  Oliva y Ocana
# 415        Saether
# 416           Ware
# ...

# %%
titanic[titanic["Name"].str.contains("Dr")]
# Out:
#      PassengerId  Survived  Pclass  \
# 138         1030         1       3
# 194         1086         0       2
# 247         1139         0       2
# 293         1185         0       1
# 343         1235         1       1
# 405         1297         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 138                              Drapkin, Miss. Jennie  female  23.0      0
# 194                      Drew, Master. Marshall Brines    male   8.0      0
# 247                             Drew, Mr. James Vivian    male  42.0      1
# 293                              Dodge, Dr. Washington    male  53.0      1
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
#
#      Parch           Ticket      Fare        Cabin Embarked Real_Name
# 138      0  SOTON/OQ 392083    8.0500          NaN        S   Drapkin
# ...
